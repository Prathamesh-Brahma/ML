# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathamesh-Brahma/ML/blob/main/ML10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ML LAB -10**
#
# **AIM: TO PERFORM HIERARCHICAL CLUSTERING USING AGGREGATIVE METHODS AND INTERPRET DENDROGRAMS FOR CLUSTERING FORMATION **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/sample_data/Mall_Customers - Mall_Customers.csv")
print(df.head())
# Out:
# Mounted at /content/drive
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
plt.figure(figsize=(10, 6))

dendrogram(linkage(X_scaled , method='ward'))

plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward)
clusters = hc.fit_predict(X_scaled)
# Out:
#   File "/tmp/ipykernel_292/1880073518.py", line 1
#     hc = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward)
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df['cluster'] = cluster
print(df.head())

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='cluster', data=df, palette = 'set1')
